# %%
# !pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mtcnn in /usr/local/lib/python3.7/dist-packages (0.1.1)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (2.8.0)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.21.6)

# %%
import cv2
import mtcnn
from mtcnn.mtcnn import MTCNN
import matplotlib.pyplot as plt
import time
start = time.time()

image_path = "omar-lopez-1qfy-jDc_jo-unsplash.jpg"
print(mtcnn.__version__)
# Out:
# 0.1.0

# %%
def detect_face(image):
    detector = MTCNN()
    bounding_boxes = detector.detect_faces(image)
    return bounding_boxes

# %%
def draw_bounding_boxes(image, bboxes):
    for box in bboxes:
        x1, y1, w, h = box['box']
        cv2.rectangle(image, (x1, y1), (x1+w,y1+h), (0,255,0), 2)

# %%
def mark_key_point(image, keypoint):
    cv2.circle(image, (keypoint), 1, (0,255,0), 2)

# %%
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

bboxes = detect_face(image)
print("Output of MTCNN detector is...\n",bboxes)
# Out:
# Output of MTCNN detector is...
#  [{'box': [588, 1118, 145, 183], 'confidence': 1.0, 'keypoints': {'left_eye': (640, 1181), 'right_eye': (704, 1200), 'nose': (669, 1212), 'mouth_left': (630, 1245), 'mouth_right': (681, 1261)}}, {'box': [3346, 966, 131, 170], 'confidence': 1.0, 'keypoints': {'left_eye': (3379, 1026), 'right_eye': (3440, 1026), 'nose': (3407, 1063), 'mouth_left': (3381, 1083), 'mouth_right': (3446, 1084)}}, {'box': [1360, 921, 123, 151], 'confidence': 0.9999997615814209, 'keypoints': {'left_eye': (1392, 975), 'right_eye': (1447, 973), 'nose': (1424, 1001), 'mouth_left': (1400, 1035), 'mouth_right': (1452, 1033)}}, {'box': [1009, 942, 153, 178], 'confidence': 0.9999997615814209, 'keypoints': {'left_eye': (1058, 1013), 'right_eye': (1128, 1018), 'nose': (1095, 1043), 'mouth_left': (1053, 1072), 'mouth_right': (1125, 1077)}}, {'box': [445, 947, 145, 172], 'confidence': 0.9999990463256836, 'keypoints': {'left_eye': (495, 1005), 'right_eye': (564, 1003), 'nose': (536, 1034), 'mouth_left': (500, 1070), 'mouth_right': (563, 1070)}}, {'box': [1742, 909, 127, 171], 'confidence': 0.9999984502792358, 'keypoints': {'left_eye': (1772, 975), 'right_eye': (1832, 973), 'nose': (1803, 1005), 'mouth_left': (1775, 1035), 'mouth_right': (1830, 1035)}}, {'box': [3202, 779, 130, 167], 'confidence': 0.9999977350234985, 'keypoints': {'left_eye': (3241, 843), 'right_eye': (3296, 849), 'nose': (3267, 874), 'mouth_left': (3237, 902), 'mouth_right': (3291, 906)}}, {'box': [1610, 1004, 131, 172], 'confidence': 0.9999938011169434, 'keypoints': {'left_eye': (1641, 1075), 'right_eye': (1702, 1072), 'nose': (1669, 1101), 'mouth_left': (1643, 1131), 'mouth_right': (1702, 1131)}}, {'box': [2398, 991, 125, 168], 'confidence': 0.9999916553497314, 'keypoints': {'left_eye': (2437, 1063), 'right_eye': (2498, 1061), 'nose': (2479, 1094), 'mouth_left': (2442, 1123), 'mouth_right': (2501, 1120)}}, {'box': [3986, 884, 149, 165], 'confidence': 0.9999910593032837, 'keypoints': {'left_eye': (4034, 947), 'right_eye': (4099, 945), 'nose': (4069, 964), 'mouth_left': (4036, 1003), 'mouth_right': (4104, 1002)}}, {'box': [4105, 1172, 145, 174], 'confidence': 0.9999892711639404, 'keypoints': {'left_eye': (4148, 1247), 'right_eye': (4213, 1245), 'nose': (4180, 1274), 'mouth_left': (4154, 1305), 'mouth_right': (4211, 1303)}}, {'box': [3032, 1125, 131, 166], 'confidence': 0.9999815225601196, 'keypoints': {'left_eye': (3057, 1193), 'right_eye': (3117, 1190), 'nose': (3079, 1221), 'mouth_left': (3058, 1250), 'mouth_right': (3120, 1247)}}, {'box': [1562, 1639, 157, 194], 'confidence': 0.9999759197235107, 'keypoints': {'left_eye': (1616, 1725), 'right_eye': (1684, 1719), 'nose': (1660, 1755), 'mouth_left': (1617, 1785), 'mouth_right': (1691, 1778)}}, {'box': [3532, 1068, 144, 181], 'confidence': 0.9999648332595825, 'keypoints': {'left_eye': (3565, 1143), 'right_eye': (3629, 1136), 'nose': (3589, 1174), 'mouth_left': (3570, 1203), 'mouth_right': (3633, 1199)}}, {'box': [2510, 834, 139, 163], 'confidence': 0.9999620914459229, 'keypoints': {'left_eye': (2550, 890), 'right_eye': (2615, 889), 'nose': (2582, 910), 'mouth_left': (2550, 950), 'mouth_right': (2612, 950)}}, {'box': [1965, 1041, 133, 157], 'confidence': 0.9999483823776245, 'keypoints': {'left_eye': (2004, 1091), 'right_eye': (2064, 1092), 'nose': (2034, 1117), 'mouth_left': (2005, 1158), 'mouth_right': (2056, 1160)}}, {'box': [3533, 845, 141, 178], 'confidence': 0.9998779296875, 'keypoints': {'left_eye': (3573, 920), 'right_eye': (3636, 920), 'nose': (3606, 948), 'mouth_left': (3574, 975), 'mouth_right': (3637, 975)}}, {'box': [3038, 918, 149, 169], 'confidence': 0.9998641014099121, 'keypoints': {'left_eye': (3081, 974), 'right_eye': (3149, 977), 'nose': (3113, 1017), 'mouth_left': (3077, 1033), 'mouth_right': (3143, 1036)}}, {'box': [3700, 874, 145, 196], 'confidence': 0.9998213648796082, 'keypoints': {'left_eye': (3741, 948), 'right_eye': (3804, 953), 'nose': (3772, 988), 'mouth_left': (3737, 1011), 'mouth_right': (3803, 1018)}}, {'box': [3036, 7 ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# draw bounding box around the detected face and mark facial keypoints
draw_bounding_boxes(image, bboxes)
mark_key_point(image, bboxes[0]['keypoints']['left_eye'])
mark_key_point(image, bboxes[0]['keypoints']['right_eye'])
mark_key_point(image, bboxes[0]['keypoints']['nose'])
mark_key_point(image, bboxes[0]['keypoints']['mouth_left'])
mark_key_point(image, bboxes[0]['keypoints']['mouth_right'])

# display the image
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.xticks([])
plt.yticks([])
plt.show()
end = time.time()
print("Time taken:",end-start," seconds")
# Out:
# Time taken: 30.990767002105713  seconds
